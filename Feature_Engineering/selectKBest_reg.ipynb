# %%
# Importing libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
housing_df = pd.read_csv("E:\\insideAIML\\ML\\housing.csv")

# %%
null_val =housing_df.columns[housing_df.isnull().sum() > 0]

# %%
housing_df.drop(null_val , axis= 1 , inplace = True )

# %%
housing_df
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
housing_df=housing_df.select_dtypes(include=[np.int64 , np.float64])

# %%
housing_df
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# ...

# %%
x = housing_df.drop(['Id','SalePrice'],axis = 1)

y = housing_df['SalePrice']

# %%
from sklearn.feature_selection import SelectKBest 
from sklearn.feature_selection import mutual_info_regression

# %%
useful_col = SelectKBest(mutual_info_regression  , k=10).fit(x,y)

# %%
useful_col
# Out:
# SelectKBest(score_func=<function mutual_info_regression at 0x0000025CD836C540>)

# %%
# imp_col.get_support()

useful_col.get_support()
# Out:
# array([False, False,  True, False,  True,  True, False, False, False,
#         True,  True, False, False,  True, False, False,  True, False,
#        False, False,  True, False,  True,  True, False, False, False,
#        False, False, False, False, False, False])

# %%
not_use_col = x.columns[useful_col.get_support() == False]   # bcoz here in x we have 33 if we use housing df it have 35 col

# %%
not_use_col
# Out:
# Index(['MSSubClass', 'LotArea', 'OverallCond', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'Fireplaces', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold'],
#       dtype='object')

# %%
x.drop(not_use_col , axis=1 , inplace=True)

# %%
x
# Out:
#       OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0               7       2003          2003          856       856       1710
# 1               6       1976          1976         1262      1262       1262
# 2               7       2001          2002          920       920       1786
# 3               7       1915          1970          756       961       1717
# 4               8       2000          2000         1145      1145       2198
# ...           ...        ...           ...          ...       ...        ...
# 1455            6       1999          2000          953       953       1647
# 1456            6       1978          1988         1542      2073       2073
# 1457            7       1941          2006         1152      1188       2340
# 1458            5       1950          1996         1078      1078       1078
# 1459            5       1965          1965         1256      1256       1256
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=50)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
r2_score(y_pred,y_test)
# Out:
# 0.7749216754555848

# %% [markdown]
# ## by using fit_transform() method
# ## K = 3    we get 3 most imp col through our data

# %%
useful_col = SelectKBest(mutual_info_regression  , k=5).fit_transform(x,y)

# %%
useful_col
# Out:
# array([[   7, 2003, 1710,    2,  548],
#        [   6, 1976, 1262,    2,  460],
#        [   7, 2001, 1786,    2,  608],
#        ...,
#        [   7, 1941, 2340,    1,  252],
#        [   5, 1950, 1078,    1,  240],
#        [   5, 1965, 1256,    1,  276]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(useful_col,y,test_size=0.2,random_state=50)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
r2_score(y_pred,y_test)
# Out:
# 0.7235160012162656
